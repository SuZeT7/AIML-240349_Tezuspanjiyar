# %%
# cost func, gradient func, accuracy func
def cost(ytru, ypred):
    a = (y - ypred) ** 2
    return a;

# %%
def gradient(ytru, upred):
    a = 2 * (upred - u)
    return a;

# %%
def accu(ytru,ypred):
    if (ytru == ypred):
        return 1;
    else:
        return 2;
